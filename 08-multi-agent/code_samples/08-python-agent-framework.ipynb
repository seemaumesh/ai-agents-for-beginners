# %% [markdown]
# # Lesson 08 - Multi-Agent Design Pattern

# %% [markdown]
# ## Setup

# %%
import logging
logging.getLogger("agent_framework.azure").setLevel(logging.ERROR)

# %pip install agent-framework azure-ai-projects azure-identity --quiet

import os
import asyncio

from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import PromptAgentDefinition, WorkflowAgentDefinition
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
project_client = AIProjectClient(
    endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    credential=DefaultAzureCredential(),
    allow_preview=True
)

# %% [markdown]
# ## Why Multi-Agent Systems?
#
# Real-world tasks like trip planning involve many different kinds of expertise — logistics, local knowledge, budgeting, and more. A single agent trying to handle everything quickly becomes unwieldy.
#
# Multi-agent systems solve this through **specialization**: each agent focuses on one area of expertise, producing higher-quality results than a generalist. They also improve **scalability** — you can add new agents (e.g., a flight specialist, a restaurant critic) without rewriting the existing workflow. The agents compose together through a structured pipeline, passing context from one to the next.

# %% [markdown]
# ## Creating Specialized Agents

# %%
planner_agent = project_client.agents.create_version(
    agent_name="TravelPlanner",
    definition=PromptAgentDefinition(
        instructions="You are a travel planning specialist. Create detailed trip itineraries based on the traveler's preferences. Include daily schedules, must-see attractions, and logistical tips.",
        model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    )
    
)

concierge_agent = project_client.agents.create_version(
    agent_name="TravelConcierge",
    definition=PromptAgentDefinition(
        instructions="You are a travel concierge who reviews and enhances trip plans. Review the plan for completeness, add local insider tips, suggest restaurants, and identify potential issues. Provide your feedback in a constructive format.",
        model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    )
)

# %% [markdown]
# ## Building a Sequential Workflow
#
# `WorkflowBuilder` lets you wire agents into a directed graph. Here we create a simple two-step pipeline: the **TravelPlanner** drafts the itinerary, then the **TravelConcierge** reviews and enhances it.

# %%
workflow_yaml = f"""
kind: Workflow
trigger:
  kind: OnConversationStart
  id: travel_planning_workflow
actions:
  - kind: SetVariable
    id: set_user_input
    variable: Local.user_input
    value: "=UserMessage(System.LastMessageText)"
  - kind: CreateConversation
    id: create_planner_conversation
    conversationId: Local.PlannerConversationId
  - kind: CreateConversation
    id: create_concierge_conversation
    conversationId: Local.ConciergeConversationId
  
  - kind: InvokeAzureAgent
    id: get_travel_plan
    description: "Get initial travel plan from planner agent"
    conversationId: "=Local.PlannerConversationId"
    agent:
      name: {planner_agent.name}
    input:
      message: "=Local.user_input"
    output:
      message: Local.planner_response

# %%
workflow_agent = project_client.agents.create_version(
    agent_name="TravelWorkflow",
    definition=WorkflowAgentDefinition(
        workflow_yaml=workflow_yaml
    )
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 workflow_agent = project_client.agents.create_version(
#       2     agent_name="TravelWorkflow",
# ----> 3     definition=WorkflowAgentDefinition(
#       4         workflow_yaml=workflow_yaml
#       5     )
#       6 )
#
# File ~/.pyenv/versions/3.14.0/lib/python3.14/site-packages/azure/ai/projects/models/_models.py:9024, in WorkflowAgentDefinition.__init__(self, *args, **kwargs)
#    9023 def __init__(self, *args: Any, **kwargs: Any) -> None:
# -> 9024     super().__init__(*args, **kwargs)
#    9025     self.kind = AgentKind.WORKFLOW
#
# File ~/.pyenv/versions/3.14.0/lib/python3.14/site-packages/azure/ai/projects/models/_models.py:321, in AgentDefinition.__init__(self, *args, **kwargs)
#     320 def __init__(self, *args: Any, **kwargs: Any) -> None:
# --> 321     super().__init__(*args, **kwargs)
#
# File ~/.pyenv/versions/3.14.0/lib/python3.14/site-packages/azure/ai/projects/_utils/model_base.py:659, in Model.__init__(self, *args, **kwargs)
#     656     non_attr_kwargs = [k for k in kwargs if k not in self._attr_to_rest_field]
#     657     if non_attr_kwargs:
#     658         # actual type errors only throw the first wrong keyword arg they see, so following that.
# --> 659         raise TypeError(f"{class_name}.__init__() got an unexpected keyword argument '{non_attr_kwargs[0]}'")
#     660     dict_to_pass.update(
#     661         {
#     662             self._attr_to_rest_field[k]._rest_name: _create_value(self._attr_to_rest_field[k], v)
#    (...)    665         }
#     666     )
#     667 super().__init__(dict_to_pass)
#
# TypeError: WorkflowAgentDefinition.__init__() got an unexpected keyword argument 'workflow_yaml'

# %%
workflow = WorkflowBuilder(start_executor=planner_agent) \
    .add_edge(planner_agent, concierge_agent) \
    .build()

last_author = None
events = workflow.run("Plan a 5-day trip to Paris for a food-loving couple on a $3000 budget.", stream=True)
async for event in events:
    if event.type == "output" and isinstance(event.data, AgentResponseUpdate):
        update = event.data
        author = update.author_name
        if author != last_author:
            if last_author is not None:
                print()
            print(f"\n{'='*50}")
            print(f"🤖 {author}:")
            print(f"{'='*50}")
            last_author = author
        print(update.text, end="", flush=True)

# %% [markdown]
# ## Adding More Agents to the Workflow
#
# One of the biggest advantages of the multi-agent pattern is how easy it is to extend. Below we add a **BudgetReviewer** agent that checks the plan against the traveler's budget, flags items that might push costs over the limit, and suggests money-saving alternatives. The workflow now runs three agents in sequence:
#
# ```
# TravelPlanner → TravelConcierge → BudgetReviewer
# ```

# %%
budget_agent = await provider.create_agent(
    name="BudgetReviewer",
    instructions="You are a budget-conscious travel advisor. Review the proposed trip plan and concierge enhancements against the traveler's stated budget. Estimate costs for flights, hotels, meals, and activities. Flag anything that risks exceeding the budget and suggest cost-saving alternatives while preserving the trip's quality.",
)

extended_workflow = WorkflowBuilder(start_executor=planner_agent) \
    .add_edge(planner_agent, concierge_agent) \
    .add_edge(concierge_agent, budget_agent) \
    .build()

last_author = None
events = extended_workflow.run("Plan a 5-day trip to Paris for a food-loving couple on a $3000 budget.", stream=True)
async for event in events:
    if event.type == "output" and isinstance(event.data, AgentResponseUpdate):
        update = event.data
        author = update.author_name
        if author != last_author:
            if last_author is not None:
                print()
            print(f"\n{'='*50}")
            print(f"🤖 {author}:")
            print(f"{'='*50}")
            last_author = author
        print(update.text, end="", flush=True)

# %% [markdown]
# ## Summary
#
# In this lesson you learned how to:
#
# 1. **Create specialized agents** — each with a focused role (planning, concierge, budget review).
# 2. **Wire agents into a sequential workflow** using `WorkflowBuilder` and `add_edge`.
# 3. **Stream output** from a multi-agent pipeline, tracking which agent is speaking.
# 4. **Extend a workflow** by adding new agents to the chain without modifying existing ones.
#
# The multi-agent design pattern keeps each agent simple while producing richer, more thoroughly reviewed results than any single agent could achieve alone.
